# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from copy import deepcopy
import time
import random
from scipy import stats
from scipy.stats import mode
import seaborn as sns
import warnings
from collections import defaultdict
warnings.filterwarnings("ignore")
from scipy.stats import chisquare

# %% [markdown]
# ## Extract potentiator hits for all antibiotics
# #### Exclude hits with two non-related antibiotics -> these go in co-linearity section

# %%
# Merge sequential and simultaneous hits into a single table

all_hits_sequential = pd.read_csv("output/04A.pair_annotation/results_allpairs_annotation_withcategories.csv", index_col=0)
all_simultaneous = pd.read_csv("output/04B.pair_annotation/results_allpairs_annotation_withcategories.csv", index_col=0)

sequential_merged = all_hits_sequential.merge(all_simultaneous[["position_i", "position_j", "pval_beta_i_on_j", 'pval_beta_i_on_j_BH_sig']], 
                                                on=["position_i", "position_j"], how="left", suffixes=["_sequential", "_simultaneous"])

simultaneous_merged = all_simultaneous.merge(all_hits_sequential[["position_i", "position_j", "pval_beta_i_on_j", 'pval_beta_i_on_j_BH_sig']], 
                                                on=["position_i", "position_j"], how="left", suffixes=[ "_simultaneous", "_sequential"])

all_hits = pd.concat([simultaneous_merged, sequential_merged])
all_hits = all_hits.drop_duplicates(subset=["position_i", "position_j"]).reset_index(drop=True)

# %%
known_antibiotic_first = all_hits.dropna(subset=["known_drug_i"]).query("pval_beta_i_on_j_BH_sig_sequential or pval_beta_i_on_j_BH_sig_simultaneous")

known_antibiotic_first['num_dependent'] = known_antibiotic_first.n_muts_i_on_branch_j + known_antibiotic_first.n_muts_same_branch
know_ab_first = known_antibiotic_first.loc[known_antibiotic_first.possible_drug_i.isnull(), :]
know_ab_first.sort_values('num_dependent', ascending=False).head(40)
# Out:
#         Unnamed: 0.1  position_i gene_name_i  position_j gene_name_j  \
# 679354        119471     1673425        None     2338994      Rv2082
# 677734         89080     1673425        None     1340208       PPE18
# 677498         81363     1673425        None      340132        PPE3
# 61929          18010     1673425        None     3883626      Rv3466
# 769002       1171597     1673425        None     2338990      Rv2082
# 75298         100874     1673425        None     3894732       PPE60
# 75457         102748     1673425        None     3446699      Rv3081
# 78372         136110     1673425        None     1722228        pks5
# 74053          85353     1673425        None     2197065      Rv1945
# 66180          36598     1673425        None     3730411       PPE54
# 765533       1085362     1673425        None     3895247       PPE60
# 759153        921320     1673425        None     2626105        esxO
# 50060            184     1673425        None     2155168        katG
# 760013        938569     1673425        None      154191        None
# 64486          28020     1673425        None     3336528        None
# 71269          68126     1673425        None     2030521        esxM
# 761509        970315     1673425        None     2240062        None
# 744809        752984     1673425        None     2030489        esxM
# 67688          45728     1673425        None     3527974       PPE53
# 73742          83095     1673425        None     4385937     Rv3900c
# 66957          42056     1673425        None     2300546       pks12
# 51249           1453     1673425        None     4247429        embB
# 61712          17195     1673425        None     2123145       lldD2
# 79590         147022     1673432        None     2338994      Rv2082
# 52502           2764     1673425        None     4247431        embB
# 65394          31380     1673425        None     3841662        None
# 677810         89973     1674048       fabG1     1340208       PPE18
# 74702          92465     1674048       fabG1     2122395       lldD2
# 677545         81919     1673432        None      340132        PPE3
# 677780         89590     1673432        None     1340208       PPE18
# 74703          92519     1673432        None     2122395       lldD2
# 678685        106443     1673432        None     2626189        None
# 678445        102054     1673432        None     2626191        None
# 678222         98018     1673432        None     2626011        esxO
# 676415         52282     1674048       fabG1     2867575        lppB
# 675769         26924     1674048       fabG1     1722228        pks5
# 676385         51945     1673432        None     2867575        lppB
# 675739         26593     1673432        None     1722228        pks5
# 676606         55633     1673432        None     2626018        esxO
# 67693          45881     1673425        None     4386108     Rv3900c
#
#         n_mutations_i  n_mutations_j  n_branches_with_i  n_branches_with_j  \
# 679354            752             19               3817              32513
# 677734            752             29               3817              21626
# 677498            752            134               3817              21827
# 61929             752            405               3817              19374
# 769002            752             17               3817              16336
# 75298             752             59               3817              17091
# 75457             752             81               3817              16441
# 78372             752              8               3817              16173
# 74053             752             61               3817               8507
# 66180             752            347               3817              15646
# 765533            752             10               3817               6699
# 759153            752             13               3817               5959
# 50060             752           1811               3817              12564
# 760013            752             25               3817               6689
# 64486             752            115               3817               6246
# 71269             752             68               3817               6159
# 761509            752              5               3817               5611
# 744809            752              5               3817               4727
# 67688             752             25               3817               3905
# 73742             752             12               3817               3531
# 66957             752            170               3817               7351
# 51249             752            819               3817               2866
# 61712             752            301               3817               3348
# 79590             106             19                523              32513
# 52502             752            791               3817               2090
# 65394             752            217               3817               4579
# 677810            138             29                602              21626
# 74702             138            254                602              19900
# 677545            106            134                523              21827
# 677780            106             29                523              21626
# 74703             106            254                523              19900
# 678685            106             43                523              24612
# 678445            106             42                523              24608
# 678222            106            159                523              19630
# 676415            138             25                602              16157
# 675769            138              8                602              16173
# 676385            106             25                523              16157
# 675739            106              8                523              16173
# 676606            106            105                523              17461
# 67693             752             45               3817                756
#
#         n_muts_i_on_branch_j  ...  in_antigen_epitope_j  in_antigen_protein_j  \
# 679354                   483  ...                 False                 False
# 677734                   369  ...                 False                  True
# 677498                   341  ...                 False                  True
# 61929                    316  ...                 False                 False
# 769002                   281  ...                 False                 False
# 75298                    214  ...                 False                  True
# 75457                    204  ...                 False                 False
# 78372                    202  ...                 False                 False
# 74053                    197  ...                 False                  True
# 66180                    164  ...                 False                  True
# 765533                   174  ...                 False                  True
# 759153                   174  ...                  True                  True
# 50060                    121  ...                 False                  True
# 760013                   173  ...                 False                 False
# 64486                    171  ...                 False                 False
# 71269                    169  ...                 False                 False
# 761509                   168  ...                 False                 False
# 744809                   152  ...                 False                 False
# 67688                    103  ...                 False                 False
# 73742                    103  ...                 False                 False
# 66957                     84  ...                 False                 False
# 51249                     20  ...                 False                 False
# 61712                     60  ...                 False                  True
# 79590                     72  ...                 False                 False
# 52502                     14  ...                 False                 False
# 65394                     61  ...                 False                 False
# 677810                    69  ...                 False                  True
# 74702                     61  ...                 False                  True
# 677545                    59  ...                 False                  True
# 677780                    59  ...                 False                  True
# 74703                     55  ...                 False                  True
# 678685                    56  ...                 False                 False
# 678445                    56  ...                 False                 False
# 678222                    54  ...                 False                  True
# 676415                    52  ...                 False                 False
# 675769                    52  ...                 False                 False
# 676385                    50  ...                 False                 False
# 675739                    49  ...                 False                 False
# 676606                    49  ...                 False                  True
# 67693                     46  ...                 False                 False
#
#         in_known_ABR_position_j         known_drug_j  in_possible_ABR_gene_j  \
# 679354                    False                  NaN                   False
# 677734                    False                  NaN                   False
# 677498                    False                  NaN                   False
# 61929                     False                  NaN                   False
# 769002                    False                  NaN                   False
# 75298                     False                  NaN                   False
# 75457                     False                  NaN                   False
# 78372                     False                  NaN                   False
# 74053                     False                  NaN                   False
# 66180                     False                  NaN                   False
# 765533                    False                  NaN                   False
# 759153                    False                  NaN                   False
# 50060                      True  INH,INH,INH,INH,INH                    True
# 760013                    False                  NaN                   False
# 64486                     False                  NaN                   False
# 71269                     False                  NaN                   False
# 761509                    False                  NaN                   False
# 744809                    False                  NaN                   False
# 67688                     False                  NaN                   False
# 73742                     False                  NaN                   False
# 66957                     False                  NaN                   False
# 51249                      True          EMB,EMB,EMB                    True
# 61712                     False                  NaN                   False
# 79590                     False                  NaN                   False
# 52502                      True          EMB,EMB,EMB                    True
# 65394                     False                  NaN                   False
# 677810                    False                  NaN                   False
# 74702                     False                  NaN                   False
# 677545                    False                  NaN                   False
# 677780                    False                  NaN                   False
# 74703                     False                  NaN                   False
# 678685                    False                  NaN                   False
# 678445                    False                  NaN                   False
# 678222                    False                  NaN                   False
# 676415                    False                  NaN                   False
# 675769                    False                  NaN                   False
# 676385                    False                  NaN                   False
# 675739                    False                  NaN                   False
# 676606                    False                  NaN                   False
# 67693                     False                  NaN                   False
#
#         possible_drug_j        annotation pval_beta_i_on_j_sequential  \
# 679354              NaN   known_AB_second                1.979419e-25
# 677734              NaN   known_AB_second                2.613815e-25
# 677498              NaN   known_AB_second                1.576695e-14
# 61929               NaN   known_AB_second                3.932368e-14
# 769002              NaN   known_AB_second                1.788039e-16
# 75298               NaN   known_AB_second                2.167253e-01
# 75457               NaN   known_AB_second                2.750482e-01
# 78372               NaN   known_AB_second                2.372470e-01
# 74053               NaN   known_AB_second                3.508221e-22
# 66180               NaN   known_AB_second                9.748129e-01
# 765533              NaN   known_AB_second                1.873377e-26
# 759153              NaN   known_AB_second                7.466363e-31
# 50060               INH  between_known_AB                9.910234e-01
# 760013              NaN   known_AB_second                3.430683e-24
# 64486               NaN   known_AB_second                7.178043e-27
# 71269               NaN   known_AB_second                5.450284e-29
# 761509              NaN   known_AB_second                6.364160e-31
# 744809              NaN   known_AB_second                1.671623e-30
# 67688               NaN   known_AB_second                8.738843e-14
# 73742               NaN   known_AB_second                9.029936e-17
# 66957               NaN   known_AB_second                8.375840e-01
# 51249               EMB  between_known_AB                9.817820e-01
# 61712               NaN   known_AB_second                1.692102e-03
# 79590               NaN   known_AB_second                1.708165e-07
# 52502               EMB  between_known_AB                9.742324e-01
# 65394               NaN   known_AB_second                2.579198e-01
# 677810              NaN   known_AB_second                6.836948e-07
# 74702               NaN   known_AB_second                6.229445e-05
# 677545              NaN   known_AB_second                5.158961e-09
# 677780              NaN   known_AB_second                3.431243e-09
# 74703               NaN   known_AB_second                2.460996e-08
# 678685              NaN   known_AB_second                9.784369e-05
# 678445              NaN   known_AB_second                9.718966e-05
# 678222              NaN   known_AB_second                6.267768e-08
# 676415              NaN   known_AB_second                1.304533e-04
# 675769              NaN   known_AB_second                1.346490e-04
# 676385              NaN   known_AB_second                4.598023e-09
# 675739              NaN   known_AB_second                2.132290e-08
# 676606              NaN   known_AB_second                4.492417e-07
# 67693               NaN   known_AB_second                1.703737e-19
#
#         pval_beta_i_on_j_BH_sig_sequential  num_dependent
# 679354                                True            483
# 677734                                True            370
# 677498                                True            344
# 61929                                 True            324
# 769002                                True            281
# 75298                                False            219
# 75457                                False            211
# 78372                                False            205
# 74053                                 True            200
# 66180                                False            179
# 765533                                True            174
# 759153                                True            174
# 50060                                False            174
# 760013                                True            173
# 64486                                 True            172
# 71269                                 True            170
# 761509                                True            168
# 744809                                True            152
# 67688                                 True            104
# 73742                                 True            104
# 66957                                False             92
# 51249                                False             80
# 61712                                False             78
# 79590                                 True             73
# 52502                                False             71
# 65394                                False             70
# 677810                                True             69
# 74702                                 True             64
# 677545                                True             59
# 677780                                True             59
# 74703                                 True             56
# 678685                                True             56
# 678445                                True             56
# 678222                                True             54
# 676415                                True             52
# 675769                                True             52
# 676385                                True             50
# 675739                                True             49
# 676606                                True             49
# 67693                                 True             49
#
# [40 rows x 38 columns]

# %%
def _process_known_hits(input_list):
    """
    splits the possible associated drugs (string separated by ,) into a list
    """
    output_list = []
    for item in input_list:
        #print(item)
        if type(item) != str:
            output_list.append(np.nan)
        else:
            splitted = item.split(",")
            exclusive= list(set(splitted))
            output_list.append(exclusive)
    return output_list

## Note! This is code recycling, actually the table contains hits where the known antibiotic resistance mutation was second
known_antibiotic_first = all_hits.dropna(subset=["known_drug_i"]).query("pval_beta_i_on_j_BH_sig_sequential or pval_beta_i_on_j_BH_sig_simultaneous")

known_antibiotic_first["known_drug_i"] = _process_known_hits(known_antibiotic_first.known_drug_i)
known_antibiotic_first["possible_drug_i"] = _process_known_hits(known_antibiotic_first.possible_drug_i)

known_antibiotic_first["known_drug_j"] = _process_known_hits(known_antibiotic_first.known_drug_j)
known_antibiotic_first["possible_drug_j"] = _process_known_hits(known_antibiotic_first.possible_drug_j)

print(len(known_antibiotic_first))
# Out:
# 3704

# %%
between_antibiotic_indices = []
antibiotic_indices = []

known_antibiotic_first["within_same_drug"] = False

for idx, row in known_antibiotic_first.iterrows():
    
    set_of_known_first = set(row.known_drug_i)
    set_of_known_second = set()
    known_drug_second = False
    
    if type(row.known_drug_j) is list:
        set_of_known_second= set(row.known_drug_j)
        known_drug_second = True
        
    elif type(row.possible_drug_j) is list:
        set_of_known_second= set(row.possible_drug_j)
        known_drug_second = True
        
    if not known_drug_second:
        antibiotic_indices.append(idx)
    
    elif len(set_of_known_first.intersection(set_of_known_second)) > 0:
        antibiotic_indices.append(idx)
        known_antibiotic_first.loc[idx, "within_same_drug"] = True
        
    else:
        between_antibiotic_indices.append(idx)
        
between_antibiotic_hits = known_antibiotic_first.loc[between_antibiotic_indices]
antibiotic_hits = known_antibiotic_first.loc[antibiotic_indices]

# %% [markdown]
# ## Compute per-drug output tables

# %%
## These will contain all hits except the between-antibiotic hits

## First get the list of all names of drugs in the dataset
drug_list = []
for idx, row in antibiotic_hits.iterrows():
    drugs1 = row.possible_drug_i
    drugs2 = row.possible_drug_j
    
    if type(drugs1) != list:
        drugs1= []
    if type(drugs2) != list:
        drugs2=[]
    
    for drug in drugs1 + drugs2:
        drug_list.append(drug)

drug_list = list(set(drug_list))

## Then create an empty df for each
df_dict = {drug:pd.DataFrame() for drug in drug_list}

## now concatenate each row to the appropriate drug dataframe
for idx, row in antibiotic_hits.iterrows():
    drugs1 = row.possible_drug_i
    drugs2 = row.possible_drug_j
    
    if type(drugs1) != list:
        drugs1= []
    if type(drugs2) != list:
        drugs2=[]
    
    for drug in drugs1:
        df_dict[drug] = df_dict[drug].append(row)
        
    for drug in drugs2:
        df_dict[drug] = df_dict[drug].append(row)
        
for drug, df in df_dict.items():
    print(drug, len(df))
    df.sort_values("n_muts_i_on_branch_j", ascending=False).to_csv(f"output/05.antibiotic/{drug}_potentiator_antibiotic_hits.csv")
    df.query("pval_beta_i_on_j_BH_sig_sequential != 0").query("pval_beta_i_on_j_BH_sig_sequential").sort_values(
        "n_muts_i_on_branch_j", ascending=False
    ).to_csv(f"output/05.antibiotic/{drug}_potentiator_antibiotic_hits_sequential.csv")
# Out:
# PZA 872
# RIF 426
# EMB 257
# ETH 172
# LZD 194
# MXF 239
# AMI 339
# LEV 239
# KAN 335
# STM 389
# INH 127
# CAP 238
