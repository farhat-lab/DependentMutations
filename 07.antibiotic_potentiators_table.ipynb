# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from copy import deepcopy
import time
import random
from scipy import stats
from scipy.stats import mode
import seaborn as sns
import warnings
from collections import defaultdict
warnings.filterwarnings("ignore")
from scipy.stats import chisquare

# %%
# !conda list -e >env.txt

# %% [markdown]
# ## Extract potentiator hits for all antibiotics

# %%
# Merge sequential and simultaneous hits into a single table

all_hits_sequential = pd.read_csv("output/04A.pair_annotation/results_allpairs_annotation_withcategories.csv", index_col=0)
all_simultaneous = pd.read_csv("output/04B.pair_annotation/results_allpairs_annotation_withcategories.csv", index_col=0)

sequential_merged = all_hits_sequential.merge(all_simultaneous[["position_i", "position_j", "pval_beta_i_on_j", 'pval_beta_i_on_j_BH_sig']], 
                                                on=["position_i", "position_j"], how="left", suffixes=["_sequential", "_simultaneous"])

simultaneous_merged = all_simultaneous.merge(all_hits_sequential[["position_i", "position_j", "pval_beta_i_on_j", 'pval_beta_i_on_j_BH_sig']], 
                                                on=["position_i", "position_j"], how="left", suffixes=[ "_simultaneous", "_sequential"])

all_hits = pd.concat([simultaneous_merged, sequential_merged])
all_hits = all_hits.drop_duplicates(subset=["position_i", "position_j"]).reset_index(drop=True)

# %%
known_antibiotic_first = all_hits.dropna(subset=["known_drug_i"]).query("pval_beta_i_on_j_BH_sig_sequential or pval_beta_i_on_j_BH_sig_simultaneous")

known_antibiotic_first['num_dependent'] = known_antibiotic_first.n_muts_i_on_branch_j + known_antibiotic_first.n_muts_same_branch
know_ab_first = known_antibiotic_first.loc[known_antibiotic_first.possible_drug_i.isnull(), :]
know_ab_first.sort_values('num_dependent', ascending=False).head(40)
# Out:
#         Unnamed: 0  position_i gene_name_i  position_j gene_name_j  \
# 662712      118419     1673425        None     2338994      Rv2082
# 661092       88288     1673425        None     1340208       PPE18
# 660856       80638     1673425        None      340132        PPE3
# 51509        11156     1673425        None     3883626      Rv3466
# 748865     1106672     1673425        None     2338990      Rv2082
# 58103        54831     1673425        None     3894732       PPE60
# 58393        56362     1673425        None     3446699      Rv3081
# 77150       132672     1673425        None     1722228        pks5
# 57700        53181     1673425        None     2197065      Rv1945
# 52824        18658     1673425        None     3730411       PPE54
# 745914     1036140     1673425        None     3895247       PPE60
# 739852      879432     1673425        None     2626105        esxO
# 49209          562     1673425        None     2155168        katG
# 740712      896410     1673425        None      154191        None
# 50377         4385     1673425        None     3336528        None
# 58090        54588     1673425        None     2030521        esxM
# 742208      927782     1673425        None     2240062        None
# 727238      734263     1673425        None     2030489        esxM
# 74812       101372     1673425        None     4385937     Rv3900c
# 56354        40738     1673425        None     3527974       PPE53
# 59113        57988     1673425        None     2300546       pks12
# 60564        60065     1673425        None     4247429        embB
# 55586        38183     1673425        None     2123145       lldD2
# 78350       143105     1673432        None     2338994      Rv2082
# 59326        58393     1673425        None     4247431        embB
# 661168       89172     1674048       fabG1     1340208       PPE18
# 54870        33539     1674048       fabG1     2122395       lldD2
# 660903       81189     1673432        None      340132        PPE3
# 661138       88794     1673432        None     1340208       PPE18
# 661803      101150     1673432        None     2626191        None
# 54871        33593     1673432        None     2122395       lldD2
# 662043      105502     1673432        None     2626189        None
# 661580       97149     1673432        None     2626011        esxO
# 659127       26687     1674048       fabG1     1722228        pks5
# 659773       51816     1674048       fabG1     2867575        lppB
# 659743       51483     1673432        None     2867575        lppB
# 659964       55138     1673432        None     2626018        esxO
# 659097       26360     1673432        None     1722228        pks5
# 53467        22606     1673425        None     4386108     Rv3900c
# 660181       58905     1673432        None     3894732       PPE60
#
#         n_mutations_i  n_mutations_j  n_branches_with_i  n_branches_with_j  \
# 662712            752             19               3817              32513
# 661092            752             29               3817              21626
# 660856            752            134               3817              21827
# 51509             752            405               3817              19374
# 748865            752             17               3817              16336
# 58103             752             59               3817              17091
# 58393             752             81               3817              16441
# 77150             752              8               3817              16173
# 57700             752             61               3817               8507
# 52824             752            347               3817              15646
# 745914            752             10               3817               6699
# 739852            752             13               3817               5959
# 49209             752           1811               3817              12564
# 740712            752             25               3817               6689
# 50377             752            115               3817               6246
# 58090             752             68               3817               6159
# 742208            752              5               3817               5611
# 727238            752              5               3817               4727
# 74812             752             12               3817               3531
# 56354             752             25               3817               3905
# 59113             752            170               3817               7351
# 60564             752            819               3817               2866
# 55586             752            301               3817               3348
# 78350             106             19                523              32513
# 59326             752            791               3817               2090
# 661168            138             29                602              21626
# 54870             138            254                602              19900
# 660903            106            134                523              21827
# 661138            106             29                523              21626
# 661803            106             42                523              24608
# 54871             106            254                523              19900
# 662043            106             43                523              24612
# 661580            106            159                523              19630
# 659127            138              8                602              16173
# 659773            138             25                602              16157
# 659743            106             25                523              16157
# 659964            106            105                523              17461
# 659097            106              8                523              16173
# 53467             752             45               3817                756
# 660181            106             59                523              17091
#
#         n_muts_i_on_branch_j  ...  in_antigen_epitope_j  in_antigen_protein_j  \
# 662712                   483  ...                 False                 False
# 661092                   369  ...                 False                  True
# 660856                   341  ...                 False                  True
# 51509                    316  ...                 False                 False
# 748865                   281  ...                 False                 False
# 58103                    214  ...                 False                  True
# 58393                    204  ...                 False                 False
# 77150                    202  ...                 False                 False
# 57700                    197  ...                 False                  True
# 52824                    164  ...                 False                  True
# 745914                   174  ...                 False                  True
# 739852                   174  ...                  True                  True
# 49209                    121  ...                 False                  True
# 740712                   173  ...                 False                 False
# 50377                    171  ...                 False                 False
# 58090                    169  ...                 False                 False
# 742208                   168  ...                 False                 False
# 727238                   152  ...                 False                 False
# 74812                    103  ...                 False                 False
# 56354                    103  ...                 False                 False
# 59113                     84  ...                 False                 False
# 60564                     20  ...                 False                 False
# 55586                     60  ...                 False                  True
# 78350                     72  ...                 False                 False
# 59326                     14  ...                 False                 False
# 661168                    69  ...                 False                  True
# 54870                     61  ...                 False                  True
# 660903                    59  ...                 False                  True
# 661138                    59  ...                 False                  True
# 661803                    56  ...                 False                 False
# 54871                     55  ...                 False                  True
# 662043                    56  ...                 False                 False
# 661580                    54  ...                 False                  True
# 659127                    52  ...                 False                 False
# 659773                    52  ...                 False                 False
# 659743                    50  ...                 False                 False
# 659964                    49  ...                 False                  True
# 659097                    49  ...                 False                 False
# 53467                     46  ...                 False                 False
# 660181                    49  ...                 False                  True
#
#         in_known_ABR_position_j         known_drug_j  in_possible_ABR_gene_j  \
# 662712                    False                  NaN                   False
# 661092                    False                  NaN                   False
# 660856                    False                  NaN                   False
# 51509                     False                  NaN                   False
# 748865                    False                  NaN                   False
# 58103                     False                  NaN                   False
# 58393                     False                  NaN                   False
# 77150                     False                  NaN                   False
# 57700                     False                  NaN                   False
# 52824                     False                  NaN                   False
# 745914                    False                  NaN                   False
# 739852                    False                  NaN                   False
# 49209                      True  INH,INH,INH,INH,INH                    True
# 740712                    False                  NaN                   False
# 50377                     False                  NaN                   False
# 58090                     False                  NaN                   False
# 742208                    False                  NaN                   False
# 727238                    False                  NaN                   False
# 74812                     False                  NaN                   False
# 56354                     False                  NaN                   False
# 59113                     False                  NaN                   False
# 60564                      True          EMB,EMB,EMB                    True
# 55586                     False                  NaN                   False
# 78350                     False                  NaN                   False
# 59326                      True          EMB,EMB,EMB                    True
# 661168                    False                  NaN                   False
# 54870                     False                  NaN                   False
# 660903                    False                  NaN                   False
# 661138                    False                  NaN                   False
# 661803                    False                  NaN                   False
# 54871                     False                  NaN                   False
# 662043                    False                  NaN                   False
# 661580                    False                  NaN                   False
# 659127                    False                  NaN                   False
# 659773                    False                  NaN                   False
# 659743                    False                  NaN                   False
# 659964                    False                  NaN                   False
# 659097                    False                  NaN                   False
# 53467                     False                  NaN                   False
# 660181                    False                  NaN                   False
#
#         possible_drug_j        annotation pval_beta_i_on_j_sequential  \
# 662712              NaN   known_AB_second                1.979419e-25
# 661092              NaN   known_AB_second                2.613815e-25
# 660856              NaN   known_AB_second                1.576695e-14
# 51509               NaN   known_AB_second                3.932368e-14
# 748865              NaN   known_AB_second                1.788039e-16
# 58103               NaN   known_AB_second                2.167253e-01
# 58393               NaN   known_AB_second                2.750482e-01
# 77150               NaN   known_AB_second                2.372470e-01
# 57700               NaN   known_AB_second                3.508221e-22
# 52824               NaN   known_AB_second                9.748129e-01
# 745914              NaN   known_AB_second                1.873377e-26
# 739852              NaN   known_AB_second                7.466363e-31
# 49209               INH  between_known_AB                9.910234e-01
# 740712              NaN   known_AB_second                3.430683e-24
# 50377               NaN   known_AB_second                7.178043e-27
# 58090               NaN   known_AB_second                5.450284e-29
# 742208              NaN   known_AB_second                6.364160e-31
# 727238              NaN   known_AB_second                1.671623e-30
# 74812               NaN   known_AB_second                9.029936e-17
# 56354               NaN   known_AB_second                8.738843e-14
# 59113               NaN   known_AB_second                8.375840e-01
# 60564               EMB  between_known_AB                9.817820e-01
# 55586               NaN   known_AB_second                1.692102e-03
# 78350               NaN   known_AB_second                1.708165e-07
# 59326               EMB  between_known_AB                9.742324e-01
# 661168              NaN   known_AB_second                6.836948e-07
# 54870               NaN   known_AB_second                6.229445e-05
# 660903              NaN   known_AB_second                5.158961e-09
# 661138              NaN   known_AB_second                3.431243e-09
# 661803              NaN   known_AB_second                9.718966e-05
# 54871               NaN   known_AB_second                2.460996e-08
# 662043              NaN   known_AB_second                9.784369e-05
# 661580              NaN   known_AB_second                6.267768e-08
# 659127              NaN   known_AB_second                1.346490e-04
# 659773              NaN   known_AB_second                1.304533e-04
# 659743              NaN   known_AB_second                4.598023e-09
# 659964              NaN   known_AB_second                4.492417e-07
# 659097              NaN   known_AB_second                2.132290e-08
# 53467               NaN   known_AB_second                1.703737e-19
# 660181              NaN   known_AB_second                1.943322e-07
#
#         pval_beta_i_on_j_BH_sig_sequential  num_dependent
# 662712                                True            483
# 661092                                True            370
# 660856                                True            344
# 51509                                 True            324
# 748865                                True            281
# 58103                                False            219
# 58393                                False            211
# 77150                                False            205
# 57700                                 True            200
# 52824                                False            179
# 745914                                True            174
# 739852                                True            174
# 49209                                False            174
# 740712                                True            173
# 50377                                 True            172
# 58090                                 True            170
# 742208                                True            168
# 727238                                True            152
# 74812                                 True            104
# 56354                                 True            104
# 59113                                False             92
# 60564                                False             80
# 55586                                False             78
# 78350                                 True             73
# 59326                                False             71
# 661168                                True             69
# 54870                                 True             64
# 660903                                True             59
# 661138                                True             59
# 661803                                True             56
# 54871                                 True             56
# 662043                                True             56
# 661580                                True             54
# 659127                                True             52
# 659773                                True             52
# 659743                                True             50
# 659964                                True             49
# 659097                                True             49
# 53467                                 True             49
# 660181                                True             49
#
# [40 rows x 38 columns]

# %%
def _process_known_hits(input_list):
    """
    splits the possible associated drugs (string separated by ,) into a list
    """
    output_list = []
    for item in input_list:
        #print(item)
        if type(item) != str:
            output_list.append(np.nan)
        else:
            splitted = item.split(",")
            exclusive= list(set(splitted))
            output_list.append(exclusive)
    return output_list

## Note! This is code recycling, actually the table contains hits where the known antibiotic resistance mutation was second
known_antibiotic_first = all_hits.dropna(subset=["known_drug_i"]).query("pval_beta_i_on_j_BH_sig_sequential or pval_beta_i_on_j_BH_sig_simultaneous")

known_antibiotic_first["known_drug_i"] = _process_known_hits(known_antibiotic_first.known_drug_i)
known_antibiotic_first["possible_drug_i"] = _process_known_hits(known_antibiotic_first.possible_drug_i)

known_antibiotic_first["known_drug_j"] = _process_known_hits(known_antibiotic_first.known_drug_j)
known_antibiotic_first["possible_drug_j"] = _process_known_hits(known_antibiotic_first.possible_drug_j)

print(len(known_antibiotic_first))
# Out:
# 3694

# %%
between_antibiotic_indices = []
antibiotic_indices = []

known_antibiotic_first["within_same_drug"] = False

for idx, row in known_antibiotic_first.iterrows():
    
    set_of_known_first = set(row.known_drug_i)
    set_of_known_second = set()
    known_drug_second = False
    
    if type(row.known_drug_j) is list:
        set_of_known_second= set(row.known_drug_j)
        known_drug_second = True
        
    elif type(row.possible_drug_j) is list:
        set_of_known_second= set(row.possible_drug_j)
        known_drug_second = True
        
    if not known_drug_second:
        antibiotic_indices.append(idx)
    
    elif len(set_of_known_first.intersection(set_of_known_second)) > 0:
        antibiotic_indices.append(idx)
        known_antibiotic_first.loc[idx, "within_same_drug"] = True
        
    else:
        between_antibiotic_indices.append(idx)
        
between_antibiotic_hits = known_antibiotic_first.loc[between_antibiotic_indices]
antibiotic_hits = known_antibiotic_first.loc[antibiotic_indices]

# %% [markdown]
# ## Compute per-drug output tables

# %%
## These will contain all hits except the between-antibiotic hits

## First get the list of all names of drugs in the dataset
drug_list = []
for idx, row in antibiotic_hits.iterrows():
    drugs1 = row.possible_drug_i
    drugs2 = row.possible_drug_j
    
    if type(drugs1) != list:
        drugs1= []
    if type(drugs2) != list:
        drugs2=[]
    
    for drug in drugs1 + drugs2:
        drug_list.append(drug)

drug_list = list(set(drug_list))

## Then create an empty df for each
df_dict = {drug:pd.DataFrame() for drug in drug_list}

## now concatenate each row to the appropriate drug dataframe
for idx, row in antibiotic_hits.iterrows():
    drugs1 = row.possible_drug_i
    drugs2 = row.possible_drug_j
    
    if type(drugs1) != list:
        drugs1= []
    if type(drugs2) != list:
        drugs2=[]
    
    for drug in drugs1:
        df_dict[drug] = df_dict[drug].append(row)
        
    for drug in drugs2:
        df_dict[drug] = df_dict[drug].append(row)
        
for drug, df in df_dict.items():
    print(drug, len(df))
    df.sort_values("n_muts_i_on_branch_j", ascending=False).to_csv(f"output/05.antibiotic/{drug}_potentiator_antibiotic_hits.csv")
    df.query("pval_beta_i_on_j_BH_sig_sequential != 0").query("pval_beta_i_on_j_BH_sig_sequential").sort_values(
        "n_muts_i_on_branch_j", ascending=False
    ).to_csv(f"output/05.antibiotic/{drug}_potentiator_antibiotic_hits_sequential.csv")
# Out:
# RIF 425
# STM 384
# KAN 333
# LEV 241
# MXF 241
# CAP 233
# LZD 193
# AMI 337
# ETH 173
# PZA 871
# EMB 257
# INH 125
