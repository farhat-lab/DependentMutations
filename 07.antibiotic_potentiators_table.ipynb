# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from copy import deepcopy
import time
import random
from scipy import stats
from scipy.stats import mode
import seaborn as sns
import warnings
from collections import defaultdict
warnings.filterwarnings("ignore")
from scipy.stats import chisquare

# %%
# !conda list -e >env.txt

# %% [markdown]
# ## Extract potentiator hits for all antibiotics

# %%
# Merge sequential and simultaneous hits into a single table

all_hits_sequential = pd.read_csv("output/04A.pair_annotation/results_allpairs_annotation_withcategories.csv", index_col=0)
all_simultaneous = pd.read_csv("output/04B.pair_annotation/results_allpairs_annotation_withcategories.csv", index_col=0)

sequential_merged = all_hits_sequential.merge(all_simultaneous[["position_i", "position_j", "pval_beta_i_on_j", 'pval_beta_i_on_j_BH_sig']], 
                                                on=["position_i", "position_j"], how="left", suffixes=["_sequential", "_simultaneous"])

simultaneous_merged = all_simultaneous.merge(all_hits_sequential[["position_i", "position_j", "pval_beta_i_on_j", 'pval_beta_i_on_j_BH_sig']], 
                                                on=["position_i", "position_j"], how="left", suffixes=[ "_simultaneous", "_sequential"])

all_hits = pd.concat([simultaneous_merged, sequential_merged])
all_hits = all_hits.drop_duplicates(subset=["position_i", "position_j"]).reset_index(drop=True)

# %%
known_antibiotic_first = all_hits.dropna(subset=["known_drug_i"]).query("pval_beta_i_on_j_BH_sig_sequential or pval_beta_i_on_j_BH_sig_simultaneous")

known_antibiotic_first['num_dependent'] = known_antibiotic_first.n_muts_i_on_branch_j + known_antibiotic_first.n_muts_same_branch
know_ab_first = known_antibiotic_first.loc[known_antibiotic_first.possible_drug_i.isnull(), :]
know_ab_first.sort_values('num_dependent', ascending=False).head(40)
# Out:
#         Unnamed: 0  position_i gene_name_i  position_j gene_name_j  \
# 527021       36273     1673425        None     1096633        None
# 528636       63830     1673425        None     2338994      Rv2082
# 527474       44432     1673425        None     1340208       PPE18
# 527709       48467     1673425        None      340132        PPE3
# 46692         5321     1673425        None     3883626      Rv3466
# 587432      577848     1673425        None     2338990      Rv2082
# 55276        57354     1673425        None     3446699      Rv3081
# 72583       120996     1673425        None     1722228        pks5
# 48537        15793     1673425        None     3730411       PPE54
# 589346      609374     1673425        None     1533583       PPE19
# 586001      555361     1673425        None     3895247       PPE60
# 580319      483946     1673425        None     2626105        esxO
# 54885        55524     1673425        None     2030521        esxM
# 47420         7999     1673425        None     3336528        None
# 585645      549271     1673425        None      154191        None
# 583116      507922     1673425        None     2240062        None
# 587263      574961     1673425        None       50557        ino1
# 45352          211     1673425        None     2155168        katG
# 527035       36420     1674048       fabG1     1096633        None
# 578670      474630     1673425        None     2030489        esxM
# 527055       36832     1673432        None     1096633        None
# 52011        38459     1673425        None     2030355        esxM
# 48209        12995     1673425        None     3136335        None
# 46594         3129     1673425        None     2123169        None
# 72461       120062     1673425        None     4385937     Rv3900c
# 52861        43395     1673425        None     3527974       PPE53
# 573399      433304     1673425        None     1094472        None
# 53271        44979     1673425        None     2300546       pks12
# 569903      419133     1673425        None     1094538        None
# 55551        58319     1673425        None     4247429        embB
# 577261      455387     1673425        None     1468150        None
# 75002       141005     1673432        None     2338994      Rv2082
# 527486       44546     1674048       fabG1     1340208       PPE18
# 57380        61260     1673425        None     4247431        embB
# 527722       48592     1674048       fabG1      340132        PPE3
# 45598          475     1673432        None     2155168        katG
# 47443         8369     1674048       fabG1     2122395       lldD2
# 527506       44880     1673432        None     1340208       PPE18
# 527742       48941     1673432        None      340132        PPE3
# 47444         8427     1673432        None     2122395       lldD2
#
#         n_mutations_i  n_mutations_j  n_branches_with_i  n_branches_with_j  \
# 527021            786              5               3817              60683
# 528636            786             19               3817              32513
# 527474            786             30               3817              21626
# 527709            786            150               3817              21827
# 46692             786            469               3817              19374
# 587432            786             18               3817              16336
# 55276             786             83               3817              16441
# 72583             786             13               3817              16173
# 48537             786            369               3817              15646
# 589346            786            116               3817              10743
# 586001            786             10               3817               6699
# 580319            786             13               3817               5959
# 54885             786             69               3817               6159
# 47420             786            116               3817               6246
# 585645            786             25               3817               6689
# 583116            786              5               3817               5611
# 587263            786             16               3817               9463
# 45352             786           2098               3817              12564
# 527035            139              5                602              60683
# 578670            786              6               3817               4727
# 527055            107              5                523              60683
# 52011             786             78               3817               5112
# 48209             786            314               3817               7632
# 46594             786            184               3817               2876
# 72461             786             14               3817               3531
# 52861             786             26               3817               3905
# 573399            786            172               3817               2328
# 53271             786            193               3817               7351
# 569903            786            263               3817               2258
# 55551             786            865               3817               2866
# 577261            786             64               3817               2194
# 75002             107             19                523              32513
# 527486            139             30                602              21626
# 57380             786            821               3817               2090
# 527722            139            150                602              21827
# 45598             107           2098                523              12564
# 47443             139            277                602              19900
# 527506            107             30                523              21626
# 527742            107            150                523              21827
# 47444             107            277                523              19900
#
#         n_muts_i_on_branch_j  ...  in_antigen_protein_j  \
# 527021                   768  ...                 False
# 528636                   491  ...                 False
# 527474                   376  ...                  True
# 527709                   318  ...                  True
# 46692                    307  ...                 False
# 587432                   282  ...                 False
# 55276                    207  ...                 False
# 72583                    209  ...                 False
# 48537                    194  ...                  True
# 589346                   181  ...                  True
# 586001                   178  ...                  True
# 580319                   178  ...                  True
# 54885                    177  ...                 False
# 47420                    173  ...                 False
# 585645                   174  ...                 False
# 583116                   170  ...                 False
# 587263                   164  ...                 False
# 45352                     90  ...                  True
# 527035                   137  ...                 False
# 578670                   110  ...                 False
# 527055                   105  ...                 False
# 52011                    101  ...                 False
# 48209                     91  ...                 False
# 46594                     86  ...                 False
# 72461                     92  ...                 False
# 52861                     91  ...                 False
# 573399                    82  ...                 False
# 53271                     73  ...                 False
# 569903                    77  ...                 False
# 55551                     11  ...                 False
# 577261                    74  ...                 False
# 75002                     71  ...                 False
# 527486                    71  ...                  True
# 57380                     10  ...                 False
# 527722                    67  ...                  True
# 45598                     49  ...                  True
# 47443                     60  ...                  True
# 527506                    61  ...                  True
# 527742                    60  ...                  True
# 47444                     58  ...                  True
#
#         in_known_ABR_position_j         known_drug_j  in_possible_ABR_gene_j  \
# 527021                    False                  NaN                   False
# 528636                    False                  NaN                   False
# 527474                    False                  NaN                   False
# 527709                    False                  NaN                   False
# 46692                     False                  NaN                   False
# 587432                    False                  NaN                   False
# 55276                     False                  NaN                   False
# 72583                     False                  NaN                   False
# 48537                     False                  NaN                   False
# 589346                    False                  NaN                   False
# 586001                    False                  NaN                   False
# 580319                    False                  NaN                   False
# 54885                     False                  NaN                   False
# 47420                     False                  NaN                   False
# 585645                    False                  NaN                   False
# 583116                    False                  NaN                   False
# 587263                    False                  NaN                   False
# 45352                      True  INH,INH,INH,INH,INH                    True
# 527035                    False                  NaN                   False
# 578670                    False                  NaN                   False
# 527055                    False                  NaN                   False
# 52011                     False                  NaN                   False
# 48209                     False                  NaN                   False
# 46594                     False                  NaN                   False
# 72461                     False                  NaN                   False
# 52861                     False                  NaN                   False
# 573399                    False                  NaN                   False
# 53271                     False                  NaN                   False
# 569903                    False                  NaN                   False
# 55551                      True          EMB,EMB,EMB                    True
# 577261                    False                  NaN                   False
# 75002                     False                  NaN                   False
# 527486                    False                  NaN                   False
# 57380                      True          EMB,EMB,EMB                    True
# 527722                    False                  NaN                   False
# 45598                      True  INH,INH,INH,INH,INH                    True
# 47443                     False                  NaN                   False
# 527506                    False                  NaN                   False
# 527742                    False                  NaN                   False
# 47444                     False                  NaN                   False
#
#         possible_drug_j        annotation  pval_beta_i_on_j_sequential  \
# 527021              NaN   known_AB_second                 7.839476e-28
# 528636              NaN   known_AB_second                 1.226391e-19
# 527474              NaN   known_AB_second                 3.146643e-22
# 527709              NaN   known_AB_second                 1.889911e-05
# 46692               NaN   known_AB_second                 2.470575e-08
# 587432              NaN   known_AB_second                 2.197887e-13
# 55276               NaN   known_AB_second                 4.914138e-01
# 72583               NaN   known_AB_second                 2.981139e-01
# 48537               NaN   known_AB_second                 4.264086e-01
# 589346              NaN   known_AB_second                 1.493815e-07
# 586001              NaN   known_AB_second                 1.007475e-25
# 580319              NaN   known_AB_second                 3.777188e-30
# 54885               NaN   known_AB_second                 1.995826e-30
# 47420               NaN   known_AB_second                 3.059820e-25
# 585645              NaN   known_AB_second                 3.889570e-22
# 583116              NaN   known_AB_second                 2.725001e-29
# 587263              NaN   known_AB_second                 9.313409e-08
# 45352               INH  between_known_AB                 1.000000e+00
# 527035              NaN   known_AB_second                 2.492056e-20
# 578670              NaN   known_AB_second                 4.856003e-10
# 527055              NaN   known_AB_second                 2.352732e-09
# 52011               NaN   known_AB_second                 8.057993e-06
# 48209               NaN   known_AB_second                 7.921586e-01
# 46594               NaN   known_AB_second                 1.092388e-13
# 72461               NaN   known_AB_second                 6.099387e-11
# 52861               NaN   known_AB_second                 2.578778e-08
# 573399              NaN   known_AB_second                 4.915686e-17
# 53271               NaN   known_AB_second                 9.975742e-01
# 569903              NaN   known_AB_second                 3.077141e-15
# 55551               EMB  between_known_AB                 9.999955e-01
# 577261              NaN   known_AB_second                 3.040646e-14
# 75002               NaN   known_AB_second                 2.410574e-06
# 527486              NaN   known_AB_second                 1.022386e-07
# 57380               EMB  between_known_AB                 9.993510e-01
# 527722              NaN   known_AB_second                 1.273452e-05
# 45598               INH  between_known_AB                 2.550422e-13
# 47443               NaN   known_AB_second                 2.096023e-04
# 527506              NaN   known_AB_second                 2.513795e-10
# 527742              NaN   known_AB_second                 2.124449e-09
# 47444               NaN   known_AB_second                 4.065884e-10
#
#        pval_beta_i_on_j_BH_sig_sequential  median_distance  num_dependent
# 527021                               True       590.477720            768
# 528636                               True       619.327023            491
# 527474                               True       559.401902            377
# 527709                               True       568.675319            321
# 46692                                True              NaN            316
# 587432                               True       769.046309            282
# 55276                               False              NaN            214
# 72583                               False              NaN            212
# 48537                               False              NaN            211
# 589346                               True       603.102116            186
# 586001                               True       789.894490            178
# 580319                               True       789.894490            178
# 54885                                True              NaN            178
# 47420                                True              NaN            175
# 585645                               True       790.333318            174
# 583116                               True       654.513863            170
# 587263                               True       613.208632            165
# 45352                               False              NaN            149
# 527035                               True       371.576279            137
# 578670                               True       538.883662            110
# 527055                               True              NaN            105
# 52011                                True              NaN            103
# 48209                               False              NaN            103
# 46594                                True              NaN             94
# 72461                                True              NaN             93
# 52861                                True              NaN             92
# 573399                               True       385.718587             83
# 53271                               False              NaN             82
# 569903                               True       387.700851             79
# 55551                               False              NaN             77
# 577261                               True       319.658785             74
# 75002                                True              NaN             72
# 527486                               True       525.274815             71
# 57380                               False              NaN             68
# 527722                               True       578.433293             67
# 45598                                True              NaN             66
# 47443                                True              NaN             63
# 527506                               True       527.981856             61
# 527742                               True       591.460788             60
# 47444                                True              NaN             59
#
# [40 rows x 39 columns]

# %%
def _process_known_hits(input_list):
    """
    splits the possible associated drugs (string separated by ,) into a list
    """
    output_list = []
    for item in input_list:
        #print(item)
        if type(item) != str:
            output_list.append(np.nan)
        else:
            splitted = item.split(",")
            exclusive= list(set(splitted))
            output_list.append(exclusive)
    return output_list

## Note! This is code recycling, actually the table contains hits where the known antibiotic resistance mutation was second
known_antibiotic_first = all_hits.dropna(subset=["known_drug_i"]).query("pval_beta_i_on_j_BH_sig_sequential or pval_beta_i_on_j_BH_sig_simultaneous")

known_antibiotic_first["known_drug_i"] = _process_known_hits(known_antibiotic_first.known_drug_i)
known_antibiotic_first["possible_drug_i"] = _process_known_hits(known_antibiotic_first.possible_drug_i)

known_antibiotic_first["known_drug_j"] = _process_known_hits(known_antibiotic_first.known_drug_j)
known_antibiotic_first["possible_drug_j"] = _process_known_hits(known_antibiotic_first.possible_drug_j)

print(len(known_antibiotic_first))
# Out:
# 5246

# %%
between_antibiotic_indices = []
antibiotic_indices = []

known_antibiotic_first["within_same_drug"] = False

for idx, row in known_antibiotic_first.iterrows():
    
    set_of_known_first = set(row.known_drug_i)
    set_of_known_second = set()
    known_drug_second = False
    
    if type(row.known_drug_j) is list:
        set_of_known_second= set(row.known_drug_j)
        known_drug_second = True
        
    elif type(row.possible_drug_j) is list:
        set_of_known_second= set(row.possible_drug_j)
        known_drug_second = True
        
    if not known_drug_second:
        antibiotic_indices.append(idx)
    
    elif len(set_of_known_first.intersection(set_of_known_second)) > 0:
        antibiotic_indices.append(idx)
        known_antibiotic_first.loc[idx, "within_same_drug"] = True
        
    else:
        between_antibiotic_indices.append(idx)
        
between_antibiotic_hits = known_antibiotic_first.loc[between_antibiotic_indices]
antibiotic_hits = known_antibiotic_first.loc[antibiotic_indices]

# %% [markdown]
# ## Compute per-drug output tables

# %%
## These will contain all hits except the between-antibiotic hits

## First get the list of all names of drugs in the dataset
drug_list = []
for idx, row in antibiotic_hits.iterrows():
    drugs1 = row.possible_drug_i
    drugs2 = row.possible_drug_j
    
    if type(drugs1) != list:
        drugs1= []
    if type(drugs2) != list:
        drugs2=[]
    
    for drug in drugs1 + drugs2:
        drug_list.append(drug)

drug_list = list(set(drug_list))

## Then create an empty df for each
df_dict = {drug:pd.DataFrame() for drug in drug_list}

## now concatenate each row to the appropriate drug dataframe
for idx, row in antibiotic_hits.iterrows():
    drugs1 = row.possible_drug_i
    drugs2 = row.possible_drug_j
    
    if type(drugs1) != list:
        drugs1= []
    if type(drugs2) != list:
        drugs2=[]
    
    for drug in drugs1:
        df_dict[drug] = df_dict[drug].append(row)
        
    for drug in drugs2:
        df_dict[drug] = df_dict[drug].append(row)
        
for drug, df in df_dict.items():
    print(drug, len(df))
    df.sort_values("n_muts_i_on_branch_j", ascending=False).to_csv(f"output/05.antibiotic/{drug}_potentiator_antibiotic_hits.csv")
    df.query("pval_beta_i_on_j_BH_sig_sequential != 0").query("pval_beta_i_on_j_BH_sig_sequential").sort_values(
        "n_muts_i_on_branch_j", ascending=False
    ).to_csv(f"output/05.antibiotic/{drug}_potentiator_antibiotic_hits_sequential.csv")
# Out:
# ETH 209
# EMB 348
# LZD 221
# LEV 358
# AMI 424
# KAN 417
# RIF 581
# INH 153
# MXF 358
# CAP 246
# STM 497
# PZA 1230
